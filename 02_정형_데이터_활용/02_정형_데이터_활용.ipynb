# %% [markdown]
# # **[2] 정형 데이터 활용**
#
# **[학습 목표]**
# 1. 정형 데이터의 형태와 특징에 대해 이해할 수 있다.
# 2. 정형 데이터의 구조를 살펴보고 활용하기 쉽게 전처리할 수 있다.

# %% [markdown]
# ## **1. 정형 데이터**

# %% [markdown]
# 정형 데이터와 비정형 데이터가 무엇인가

# %% [markdown]
# ### **(1) 정형 데이터의 특징**

# %% [markdown]
# > 표 형태, 속성+속성값, 관리하기 용이함

# %% [markdown]
# ### **(2) 정형 데이터 수집**

# %% [markdown]
# > 캐글, 공공기관 사이트에서 다운로드 가능
# > 여러 분야의 방대한 데이터 제공

# %% [markdown]
# ### **(3) 정형 데이터의 형태**

# %% [markdown]
# > CSV 파일로 이루어져 있음
# > CSV 그림과 설명

# %% [markdown]
# ## **2. 데이터 전처리**

# %% [markdown]
# > pandas 라이브러리에 대한 설명
# > pandas의 용도, 특징

# %% [markdown]
# > titanic 데이터 전처리하기(수학과 함께하는 고교 AI 입문 60p~)
