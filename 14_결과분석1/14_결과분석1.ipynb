# %% [markdown]
# # **[14] 인공지능 추론결과에 대한 이해**
#
# **[학습 목표]**
# 1. 인공지능 프로젝트 사이클에서 평가의 중요도를 알 수 있다.
# 2. 인공지능 학습 시 데이터셋을 분리하는 목적을 이해할 수 있다.
# 3. 회귀모델의 성능평가지표를 이해하고 적용할 수 있다.

# %% [markdown]
# ## **1. 인공지능 평가**

# %% [markdown]
# ### **(1) 인공지능 모델 성능 평가**

# %% [markdown]
# > 기계 학습에 다양한 알고리즘이 존재하며, 개발자가 선택하여 모델을 생성한다. 알고리즘
# 을 잘못 적용하면, 생성한 모델은 사용할 수 없으며, 이 경우 모델을 통한 결과를 신뢰하
# 면 안된다.
# > **좀 더 찾아보기**

# %% [markdown]
# ### **(2) 학습/평가 데이터셋 분리**

# %% [markdown]
# > 학습할 때 학습/평가 데이터셋을 분리하는 것을 보았음
# > 이는 평가할 때 학습에 사용되었던 데이터를 사용하지 않게 하기 위함
# > 나눌 때의 주의사항
# > 그때그때 확인하기 위해 validation set도 있음(train set과의 차이점)

# %% [markdown]
# > 코드 예시 → 테스트 셋이랑 트레인 셋이 같을 때 정확도에 어떤 영향을 주는지

# %% [markdown]
# ## **2. 회귀모델 평가**

# %% [markdown]
# > MAE, MAPE, MSE, RMSE 등이 있음
# > * MSE 표현식
# >
# > 모두 sklearn으로 계산 가능

# %%
실습: 선형회귀 데이터에 다양한 회귀모델 loss 적용
