# %% [markdown]
# # **[15] 인공지능 추론결과에 대한 이해**
#
# **[학습 목표]**
# 1. 분류모델의 각 성능평가지표의 장단점을 이해한다.
# 2. 상황에 따라 적절한 성능평가지표를 사용할 수 있다.

# %% [markdown]
# ## **1. 분류모델 평가**

# %% [markdown]
# ### **(1) 분류모델 평가지표**

# %% [markdown]
# > confusion matrix란 TP/FP 등을 작성한 matrix
# > 정확도, 정밀도, 재현율, F1
# > 각 지표에 대한 설명

# %%
실습: (load_breast_cancer-유방암 데이터분석 정답, 예측 데이터를 주고) 데이터로 confusion matrix 그리고 각 평가지표 계산하기

# %% [markdown]
# ### **(2) 평가지표의 올바른 사용**

# %% [markdown]
# > 각 평가지표는 장단점이 있으므로 올바르게 사용해야 하며, 여러 지표를 동시에 보면 좋다.

# %% [markdown]
# > - 정확도의 단점: 라벨 간 개수 편차가 클 경우 정확도가 높다고 무조건 좋은 모델이 아님
# > - 재현율: 실제 positive를 negative로 예측하면 문제가 될 때
# > - 정밀도: 실제 negative를 positive로 예측하면 문제가 될 때

# %% [markdown]
# > F1: 라벨 간 불균형해도 정확하게 평가 가능
# > F1 수식

# %%
실습: (유방암 다른 예측 데이터를 주고) 데이터로 confusion matrix 그리고 F1 비교하기
